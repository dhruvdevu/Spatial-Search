# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
n_vals = np.arange(20, 50, 3)
psums = [0.12462, 0.123365, 0.122416,0.121674, 0.121078, 0.120589, 0.12018,  0.119833, 0.119536, 0.119277]
apsums = [0.161015, 0.154336, 0.149338, 0.145484, 0.14241, 0.139911, 0.137833, 0.136084, 0.134588, 0.133296]
true_val = 0.116*np.ones(len(n_vals))
plt.plot(n_vals,psums, label="$S_{j, d}$")
plt.plot(n_vals,apsums, label = "$S_{j, d} (w)$ (aperiodic)")
plt.plot(n_vals, true_val, label="$I_{jd}$")
plt.xlabel("n")
plt.ylabel("$S_{jd}$")
plt.legend()

# %%
#polyfit
deg = 4
z, residuals, _, _, _ = np.polyfit(1/n_vals, psums, deg, full=True)
chisq_dof = residuals/(len(psums) - deg - 1)
print(z)
print(chisq_dof)
p = np.poly1d(z)
fitvals = p(1/n_vals)
#plt.plot(n_vals, apsums)
plt.plot(n_vals, fitvals)
# Out:
# [-25.85598498   3.7196083    0.09555949   0.16970277   0.11559262]
# [6.7776771e-14]

# %%
# n = 31, 100 random points
points = np.array([[26,31,28,28,25,],[20,29,13,23,7,],[26,27,2,13,17,],[10,31,12,12,5,],[6,8,7,11,28,],[28,21,14,7,20,],[29,27,11,25,16,],[6,10,4,19,31,],[14,29,30,26,22,],[10,9,7,15,10,],[22,29,11,18,7,],[16,13,30,20,24,],[18,22,15,17,4,],[7,5,14,21,31,],[27,1,24,2,20,],[20,18,9,11,23,],[2,10,25,22,15,],[12,20,22,17,22,],[30,23,15,27,21,],[17,19,30,6,2,],[27,17,12,20,29,],[2,24,19,21,1,],[29,28,1,30,3,],[6,14,11,4,21,],[19,9,26,4,10,],[3,27,3,3,27,],[5,1,18,21,8,],[6,11,19,14,4,],[14,20,12,10,6,],[7,15,5,3,7,],[20,10,13,14,4,],[14,19,5,9,1,],[22,26,7,26,31,],[3,15,26,26,1,],[26,9,29,8,15,],[18,18,24,17,15,],[14,30,21,27,13,],[23,13,3,31,12,],[8,11,27,4,15,],[11,15,22,24,3,],[25,17,29,4,28,],[15,28,27,6,24,],[21,3,6,12,2,],[26,4,13,7,6,],[25,27,5,28,27,],[16,7,11,29,11,],[9,24,2,12,10,],[8,27,30,11,8,],[26,21,3,11,14,],[30,14,29,13,11,],[29,4,5,5,19,],[9,21,26,12,15,],[31,2,17,27,5,],[28,24,3,19,10,],[17,21,31,3,7,],[29,18,29,9,31,],[17,23,12,28,12,],[21,30,31,10,1,],[15,17,17,8,16,],[17,9,8,11,1,],[1,10,21,9,11,],[19,13,28,22,1,],[1,22,4,29,25,],[20,7,29,22,28,],[18,16,23,17,23,],[22,1,26,16,31,],[27,27,5,5,8,],[29,28,30,1,13,],[14,16,4,28,30,],[30,15,27,28,14,],[7,11,29,26,25,],[23,24,30,12,16,],[3,12,28,25,24,],[10,7,12,22,8,],[4,21,15,5,13,],[28,3,22,3,16,],[20,8,9
plt.scatter(l1dist, sums)
plt.show()
plt.scatter(l2dist, sums)
plt.show()

# %%
dist0 = np.linalg.norm(points - np.ones(5), axis=1, ord=1)
dist31 = np.linalg.norm(points - np.full(5, 31), axis=1, ord=1)

plt.scatter(dist0, sums)
plt.show()
plt.scatter(dist31, sums)
plt.show()

# %%
for i in range(len(points)):
    #outliers -
    # if np.linalg.norm(points[i]-center, ord=1) < 45 and sums[i] > 0.15:
    #transients -
    if sums[i] > 0.15:
        print(i)
        print(points[i])
# Out:
# 12
# [ 3 43 27 40 12]
# 13
# [ 1 33 27 21 18]
# 15
# [43 12 31 24 34]
# 23
# [22 36 10  5 43]
# 33
# [ 5 11 15 24 43]
# 40
# [ 6 43 14 25 12]
# 54
# [ 4 42 15 28  1]
# 56
# [20  4  1 11 19]
# 57
# [40 17 12 24  1]
# 61
# [41  1 16 38 13]
# 64
# [36  1  6 24 29]
# 67
# [17 43 11  5 13]
# 68
# [26 15 12  2  1]
# 71
# [ 1 21  8 38  9]
# 74
# [ 2  1 15 33 24]
# 75
# [21 32  1 10 40]
# 84
# [ 1 21 33 27 33]
# 87
# [21 43 11 19  9]
# 89
# [43 12 32 39 11]
# 90
# [19  3  4 43 37]
# 97
# [35 26 31 28  1]

# %%
#weirdnorms = [max(max(abs(p)), max(abs(p-31))) for p in points]
maxnorms = l1dist = np.linalg.norm(points - center, axis=1, ord=np.inf)
plt.scatter(maxnorms, sums)
plt.show()

# %%
for i in range(len(sums)):
    if sums[i] > 0.18:
        print(points[i], sums[i], maxnorms[i])
# Out:
# [31 32  4  1  1] 0.230181 16.0
# [29  1 23 31  1] 0.192659 15.0
# [31  1  9 32 13] 0.191958 16.0
# [32  9  1 28 13] 0.188763 16.0
# [14  8 32  4  1] 0.188992 16.0
# [ 1 18 30 32  6] 0.189656 16.0

# %%
#n=21 to 45, w[0]=3
sums = -np.array([-0.16568,-0.135497,-0.111583,-0.0923658,-0.0767276,-0.0638547,-0.0531465,-0.0441534,-0.0365344,-0.0300278,-0.0244304,-0.0195828,-0.0153584,])
n_vals = np.arange(21,46,2)
plt.plot(n_vals,sums, label="error sum", linestyle="", marker="o")
plt.xlabel("n")
plt.ylabel("$error$")
plt.yscale('log')
plt.legend()

# %%
deg = 4
z, residuals, _, _, _ = np.polyfit(1/n_vals, sums, deg, full=True)
chisq_dof = residuals/(len(psums) - deg - 1)
print(z)
print(chisq_dof)
p = np.poly1d(z)
fitvals = p(1/n_vals)
plt.plot(n_vals, sums, label="real")
plt.plot(n_vals, fitvals, label="fit")
plt.legend()
# Out:
# [-2.88248035e+03 -1.42051344e+02  1.05740663e+02 -3.67741473e-01
#  -2.64238772e-02]
# [4.7285101e-12]

# %%
#n_vals = np.arange(21,50,2)
plt.plot(n_vals,error1sums, label="error1 sum", linestyle="", marker="o")
plt.plot(n_vals,error2sums, label="error2 sum", linestyle="", marker="o")
#plt.plot(n_vals,, label="1/n^2.5")
# new_points = 100*np.array([1/(j ** 2) for j in np.arange(21,50,2)])
# plt.plot(n_vals, new_points, label="1/n^2.5")

plt.xlabel("n")
plt.ylabel("$error1$")
plt.yscale('log')
plt.xscale('log')
plt.legend()

# %%
n_vals = np.arange(20, 50, 3)
psums = [0.12462, 0.123365, 0.122416,0.121674, 0.121078, 0.120589, 0.12018,  0.119833, 0.119536, 0.119277]
apsums = [0.161015, 0.154336, 0.149338, 0.145484, 0.14241, 0.139911, 0.137833, 0.136084, 0.134588, 0.133296]
true_val = 0.116*np.ones(len(n_vals))
plt.plot(n_vals,psums-true_val, label="periodic error", linestyle="", marker="o")
plt.plot(n_vals,apsums-true_val, label="aperiodic error", linestyle="", marker="o")
#plt.plot(n_vals,, label="1/n^2.5")
# new_points = 100*np.array([1/(j ** 2) for j in np.arange(21,50,2)])
# plt.plot(n_vals, new_points, label="1/n^2.5")

plt.xlabel("n")
plt.ylabel("$error$")
plt.yscale('log')
plt.xscale('log')
plt.legend()

# %%
#polyfit
deg = 1
z, residuals, _, _, _ = np.polyfit(np.log(n_vals), np.log(apsums-true_val), deg, full=True)
chisq_dof = residuals/(len(psums) - deg - 1)
print(z)
print(chisq_dof)
p = np.poly1d(z)
fitvals = p(np.log(n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(apsums-true_val), marker="o", linestyle="")
# Out:
# [-1.11808136  0.2438881 ]
# [8.43708415e-06]

# %%
the error1 and error2 terms dont add up to the true error? check w

# %%
n_vals = np.arange(21,50,2)
periodic_sums = np.array([0.1156193165,0.1156220532,0.1156239864,0.1156253903,0.1156264344,0.1156272269,0.1156278391,0.1156283196,0.1156287019,0.1156290099,0.1156292608,0.1156294672,0.1156296385,0.115629782,0.115629903,])
aperiodic_single_axis_w0_sums = np.array([0.1229819653,0.1223467655,0.1218123472,0.1213565379,0.1209632129,0.1206203683,0.1203188855,0.1200517145,0.1198133199,0.1195992946,0.1194060872,0.1192308036,0.1190710621,0.1189248849,0.1187906156,])
aperiodic_single_axis_w1_sums = np.array([0.1229822802,0.1223469647,0.1218124782,0.1213566269,0.1209632751,0.1206204128,0.120318918,0.1200517387,0.1198133382,0.1195993087,0.1194060981,0.1192308122,0.119071069,0.1189248904,0.11879062,])
error1w0sums = np.zeros(len(n_vals))
error2w0sums = np.array([0.007362648848,0.006724712273,0.006188360798,0.005731147538,0.005336778478,0.00499314141,0.004691046334,0.004423394951,0.004184617977,0.003970284719,0.003776826406,0.003601336418,0.003441423589,0.003295102843,0.003160712528,])
error1w1sums = np.array([0.0003444069208,0.0002880058941,0.0002443246684,0.0002098300917,0.0001821281351,0.0001595528272,0.0001409172207,0.0001253578282,0.0001122347042,0.000101065638,9.148181787e-05,8.319734392e-05,7.598786992e-05,6.967538653e-05,6.411721123e-05,])
error2w1sums = np.array([0.007018241927,0.006436706378,0.00594403613,0.005521317446,0.005154650343,0.004833588583,0.004550129113,0.004298037123,0.004072383273,0.003869219081,0.003685344588,0.003518139074,0.003365435719,0.003225427456,0.003096595317,])
#true_vals = 0.115629*np.ones(len(n_vals))
true_vals = 0.11563081248402311792*np.ones(len(n_vals))
plt.plot(n_vals,periodic_sums, label="$S_{j, d}$")
plt.plot(n_vals,aperiodic_single_axis_w0_sums, label = "$S_{j, d} (w)$ (aperiodic)")
plt.plot(n_vals, true_vals, label="$I_{jd}$")
plt.xlabel("n")
plt.ylabel("$S_{jd}$")
plt.legend()

# %%
#plt.plot(n_vals, periodic_sums-true_vals)
plt.plot(n_vals, aperiodic_single_axis_w0_sums-periodic_sums, label='true_error')
plt.plot(n_vals, error1w0sums+error2w0sums, label='calc_error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()
v1 = aperiodic_single_axis_w0_sums-periodic_sums
v2 = error1w0sums+error2w0sums
print(np.linalg.norm(v1-v2))
# Out:
# 1.5564702735242275e-10

# %%
#polyfit
deg = 1
z, residuals, _, _, _ = np.polyfit(np.log(1/n_vals), np.log(error2w0sums), deg, full=True)
chisq_dof = residuals/(len(error2w0sums) - deg - 1)
print(z)
print(chisq_dof)
p = np.poly1d(z)
fitvals = p(np.log(1/n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(error2w0sums), marker="o", linestyle="")
# Out:
# [ 0.99814484 -1.87220058]
# [1.46371935e-08]

# %%
#polyfit
deg = 1
z, residuals, _, _, _ = np.polyfit(np.log(n_vals), np.log(aperiodic_single_axis_w0_sums-true_vals), deg, full=True)
chisq_dof = residuals/(len(periodic_sums) - deg - 1)
print(z)
print(chisq_dof)
p = np.poly1d(z)
fitvals = p(np.log(n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(aperiodic_single_axis_w0_sums-true_vals), marker="o", linestyle="", label="ap error")
plt.plot(np.log(n_vals), np.log(true_vals - periodic_sums), marker="o", linestyle="", label = "p error")
plt.legend()
# Out:
# [-0.996733   -1.87786374]
# [4.53145618e-08]

# %%
#polyfit
deg = 1
#print(np.log(true_vals - periodic_sums))
z, residuals, _, _, _ = np.polyfit(np.log(n_vals), np.log(true_vals - periodic_sums), deg, full=True)
chisq_dof = residuals/(len(periodic_sums) - deg - 1)
print(z)
#print(chisq_dof)
p = np.poly1d(z)
fitvals = p(np.log(n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(true_vals - periodic_sums), marker="o", linestyle="")
# Out:
# [-2.99447651 -2.25597198]

# %%
#polyfit
apsums = np.array([0.1233466699,0.1226500719,0.1220685152,0.1215757391,0.1211528947,0.1207861069,])
true_vals = 0.11563081248402311792*np.ones(len(apsums))
n_vals = np.array([21,23,25,27,29,31])-1
deg = 1
z, residuals, _, _, _ = np.polyfit(np.log(n_vals), np.log(np.abs(apsums-true_vals)), deg, full=True)
print(z)
p = np.poly1d(z)
fitvals = p(np.log(n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(np.abs(apsums-true_vals)), marker="o", linestyle="")
# Out:
# [-0.99457681 -1.88486848]

# %%
#polyfit
apsums = np.array([0.1585404201,0.1543220006,0.150850705,0.1479456588,0.1454796802,0.1433608222,0.1415210127,0.1399088072,0.138484623,0.1372175181,])
true_vals = 0.11563081248402311792*np.ones(len(apsums))
n_vals = np.arange(21,40,2)
deg = 1
z, residuals, _, _, _ = np.polyfit(np.log(n_vals), np.log(np.abs(apsums-true_vals)), deg, full=True)
print(z)
p = np.poly1d(z)
fitvals = p(np.log(n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(np.abs(apsums-true_vals)), marker="o", linestyle="")
# Out:
# [-1.10893081  0.22442285]

# %%
apsums = np.array([0.1229819653,0.1223467655,0.1218123472,0.1213565379,0.1209632129,])
psums = np.array([0.1156193165,0.1156220532,0.1156239864,0.1156253903,0.1156264344,])
true_vals = 0.115629*np.ones(len(psums))
n_vals = np.arange(21, 30, 2)
e1sums = np.array([0,0,0,0,0])
e2sums = np.array([0.007362648848,0.006724712273,0.006188360798,0.005731147538,0.005336778478,])
print(apsums-psums-e1sums-e2sums)
# Out:
# [-4.80000041e-11  2.69999908e-11  2.00000086e-12  6.19999998e-11
#   2.19999999e-11]

# %%
from sklearn.utils.extmath import cartesian
d = 2
n = 3
def ktuples(r):
    karr = np.arange(0,r)
    dupl = np.tile(karr, (d,1))
    cart = cartesian(dupl)
    # remove [00000]
    return cart[1:]
kvals = ktuples(n)
def pterm(k0, k1):
    return 1.0/(2-np.cos(2*np.pi*k0/3)-np.cos(2*np.pi*k1/3))
def apterm(k0, k1):
    return (np.cos(np.pi*k0/2)**2)/(2-np.cos(2*np.pi*k0/3)-np.cos(2*np.pi*k1/3))
def errorterm(k0, k1):
    return np.cos(np.pi*k0)/(2-np.cos(2*np.pi*k0/3)-np.cos(2*np.pi*k1/3))
def e2term(k):
    

pterms = [pterm(i,j) for (i,j) in kvals]
apterms = [apterm(i,j) for (i,j) in kvals]
errorterms = [errorterm(i,j) for (i,j) in kvals]
print(pterms, apterms) 
print(sum(apterms)/9-0.5*sum(pterms)/9, 0.5*sum(errorterms)/9)
# Out:
# [0.6666666666666667, 0.6666666666666665, 0.6666666666666666, 0.3333333333333333, 0.33333333333333326, 0.6666666666666665, 0.3333333333333333, 0.33333333333333326] [0.6666666666666667, 0.6666666666666665, 2.4995996377697627e-33, 1.2497998188848813e-33, 1.2497998188848812e-33, 0.6666666666666665, 0.3333333333333333, 0.33333333333333326]
# 0.07407407407407401 0.07407407407407406

# %%
i17 = 0.078136165399131999767*np.ones(4)
sums = np.array([0.1620784213,0.1453878647,0.1341406921, 0.1260719843])
n_vals = np.arange(11,18,2)
deg = 1
z, residuals, _, _, _ = np.polyfit(np.log(n_vals), np.log(np.abs(sums-i17)), deg, full=True)
print(z)
p = np.poly1d(z)
fitvals = p(np.log(n_vals))
#plt.plot(n_vals, apsums)
plt.plot(np.log(n_vals), fitvals)
plt.plot(np.log(n_vals), np.log(np.abs(sums-i17)), marker="o", linestyle="")
# Out:
# [-1.2874486  0.6065863]
